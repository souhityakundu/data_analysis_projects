# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("F:\\2.MTech(DATASET)\\Exp_2\\Teflon_G4_06.02.2023.csv")
df.head(10)
# Out:
#    Time      Force    Stroke    Stress    Strain  Tr Stress  Tr Strain  \
# 0  0.00   0.603994  0.000000  0.019100  0.000000   0.019100   0.000000
# 1  0.02   0.635783  0.000771  0.020106  0.000020   0.020106   0.000020
# 2  0.04   0.635783  0.007229  0.020106  0.000187   0.020109   0.000187
# 3  0.06   0.635783  0.020646  0.020106  0.000535   0.020116   0.000535
# 4  0.08   0.635783  0.041146  0.020106  0.001067   0.020127   0.001066
# 5  0.10   0.635783  0.066875  0.020106  0.001734   0.020141   0.001733
# 6  0.12  20.535790  0.096417  0.649412  0.002500   0.651036   0.002497
# 7  0.14  32.536190  0.129083  1.028906  0.003348   1.032350   0.003342
# 8  0.16  47.715500  0.163729  1.508928  0.004246   1.515335   0.004237
# 9  0.18  64.484280  0.199354  2.039214  0.005170   2.049757   0.005157
#
#      offset  Unnamed: 8
# 0  0.000000   -3.958048
# 1  0.000020   -3.906735
# 2  0.000188   -3.906568
# 3  0.000536   -3.906220
# 4  0.001069   -3.905689
# 5  0.001738   -3.905022
# ...

# %%
df = df.iloc[:,:-1]
df.shape
# Out:
# (2708, 7)

# %%
df.head(5)
# Out:
#    Time     Force    Stroke    Stress    Strain  Tr Stress  Tr Strain  \
# 0  0.00  0.603994  0.000000  0.019100  0.000000   0.019100   0.000000
# 1  0.02  0.635783  0.000771  0.020106  0.000020   0.020106   0.000020
# 2  0.04  0.635783  0.007229  0.020106  0.000187   0.020109   0.000187
# 3  0.06  0.635783  0.020646  0.020106  0.000535   0.020116   0.000535
# 4  0.08  0.635783  0.041146  0.020106  0.001067   0.020127   0.001066
#
#      offset
# 0  0.000000
# 1  0.000020
# 2  0.000188
# 3  0.000536
# 4  0.001069

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2708 entries, 0 to 2707
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Time       2708 non-null   float64
#  1   Force      2708 non-null   float64
#  2   Stroke     2708 non-null   float64
#  3   Stress     2708 non-null   float64
#  4   Strain     2708 non-null   float64
#  5   Tr Stress  2708 non-null   float64
#  6   Tr Strain  2708 non-null   float64
#  7   offset     2708 non-null   float64
# dtypes: float64(8)
# memory usage: 169.4 KB

# %%
plt.figure(figsize=[12,12])
plt.title("")
plt.xlabel("Strain")
plt.ylabel("Stress")
plt.scatter(df.iloc[:,0],df.iloc[:,1],)
plt.grid()
plt.ylim(0,25)

# %%
y=0
for i in range(df.shape[0]):
    if(i==10):
        slope = (df["Stress"][10]-df["Stress"][0])/(df["Strain"][10]-df["Strain"][0]) 
        break
print(slope)
# Out:
# 406.0001221259675
